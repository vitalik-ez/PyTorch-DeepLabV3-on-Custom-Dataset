# %%
import albumentations as A
import glob
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

# %%
train_images = glob.glob('../input/Water_Bodies_Dataset_Split/train_images/*')
train_masks = glob.glob('../input/Water_Bodies_Dataset_Split/train_masks/*')

train_images.sort()
train_masks.sort()

# %%
train_image_transform = A.Compose([
#     A.Resize(img_size, img_size, always_apply=True),
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.2),
])

# %%
for i in range(10):
    print(train_images[i])
    image = np.array(Image.open(train_images[i]).convert('RGB'))
    mask = np.array(Image.open(train_masks[i]).convert('RGB'))
    
    transformed = train_image_transform(image=image, mask=mask)
    image = transformed['image']
    mask = transformed['mask']
    
    plt.figure(figsize=(12, 9))
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.axis('off')
    plt.subplot(1, 2, 2)
    plt.imshow(mask)
    plt.axis('off')
    plt.show()
# Out:
# ../input/Water_Bodies_Dataset_Split/train_images/water_body_10.jpg
# ../input/Water_Bodies_Dataset_Split/train_images/water_body_100.jpg
# ../input/Water_Bodies_Dataset_Split/train_images/water_body_1000.jpg
# ../input/Water_Bodies_Dataset_Split/train_images/water_body_1002.jpg
# ../input/Water_Bodies_Dataset_Split/train_images/water_body_1004.jpg
# ../input/Water_Bodies_Dataset_Split/train_images/water_body_1006.jpg
# ../input/Water_Bodies_Dataset_Split/train_images/water_body_1008.jpg
# ../input/Water_Bodies_Dataset_Split/train_images/water_body_101.jpg
# ../input/Water_Bodies_Dataset_Split/train_images/water_body_1010.jpg
# ../input/Water_Bodies_Dataset_Split/train_images/water_body_1011.jpg
